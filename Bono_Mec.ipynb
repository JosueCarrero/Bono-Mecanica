# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 100, 10000)
w_1 = 10
r_i = 0.0001

def phi(t, w):
    return w * t

def r(phif, r_1):
    return (r_i / 2) * np.exp(phif) + (r_i / 2) * np.exp(-phif)

def plot_recorrido(w, ri):
    t = np.linspace(0, 100, 10000)
    phii = phi(t, w)
    radial = r(phii, ri)
    x = radial * np.cos(phii)
    y = radial * np.sin(phii)

    plt.plot(x, y)
    plt.grid()
    plt.axhline(0, color='red')
    plt.axvline(0, color='red')
    plt.xlim(-1, 1)
    plt.ylim(-1, 1)
    plt.show()

plot_recorrido(w_1, r_i)
# Out:
# /tmp/ipykernel_67/1329188570.py:12: RuntimeWarning: overflow encountered in exp
#   return (r_i / 2) * np.exp(phif) + (r_i / 2) * np.exp(-phif)

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 100, 10000)
w_1 = 0.1
r_i = 0.0001

def phi(t, w):
    return w * t

def r(phif, r_1):
    return (r_i / 2) * np.exp(phif) + (r_i / 2) * np.exp(-phif)

def plot_recorrido(w, ri):
    t = np.linspace(0, 100, 10000)
    phii = phi(t, w)
    radial = r(phii, ri)
    x = radial * np.cos(phii)
    y = radial * np.sin(phii)

    plt.plot(x, y)
    plt.grid()
    plt.axhline(0, color='red')
    plt.axvline(0, color='red')
    plt.xlim(-1, 1)
    plt.ylim(-1, 1)
    plt.show()

plot_recorrido(w_1, r_i)
